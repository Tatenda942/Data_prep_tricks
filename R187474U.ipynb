# %% [markdown]
# # R187474U   : CTHSC

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('players_20.csv')

# %%
df.shape
# Out:
# (18278, 104)

# %%
pd.set_option('display.max_columns',None)
df.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#    height_cm  weight_kg nationality          club  overall  potential  \
# 0        170         72   Argentina  FC Barcelona       94         94
# 1        187         83    Portugal      Juventus       93         93
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000       RW, CF, ST           Left
# 1   58500000    405000           ST, LW          Right
#
#    international_reputation  weak_foot  skill_moves   work_rate   body_type  \
# 0                         5          4            4  Medium/Low       Messi
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() #Creating an instamce of Label Encoder

# %%
#df.player_url = le.fit_transform(df.player_url)
df.short_name = le.fit_transform(df.short_name)
df.long_name = le.fit_transform(df.long_name)
#df.dob = le.fit_transform(df.dob)
#df.nationality = le.fit_transform(df.nationality)
df.club = le.fit_transform(df.club)
df.player_positions = le.fit_transform(df.player_positions)
df.preferred_foot = le.fit_transform(df.preferred_foot)
df.work_rate = le.fit_transform(df.work_rate)
df.body_type = le.fit_transform(df.body_type)
df.real_face =le.fit_transform(df.real_face)
#df.release_clause_eur = le.fit_transform(df.release_clause_eur)
#df.player_tags =le.fit_transform(df.player_tags)
#df.team_position =le.fit_transform(df.team_position)
#df.player_traits =le.fit_transform(df.player_traits)
#df.joined=le.fit_transform(df.joined)
#df.nation_position = fit_transform(df.nation_position)
#df.=le.fit_transform(df.)

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  short_name  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...        9723
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...        3164
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...       12658
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...        7851
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...        4459
#
#    long_name  age         dob  height_cm  weight_kg nationality  club  \
# 0       9790   32  1987-06-24        170         72   Argentina   224
# 1       3180   34  1985-02-05        187         83    Portugal   350
# 2      12430   27  1992-02-05        175         68      Brazil   462
# 3       7316   26  1993-01-07        188         87    Slovenia    63
# 4       4367   28  1991-01-07        175         74     Belgium   505
#
#    overall  potential  value_eur  wage_eur  player_positions  preferred_foot  \
# ...

# %%
dfmissing=df.isna()
dfmissingsum=dfmissing.sum()
(dfmissingsum/len(df))*100
df.isna().mean().round(4)*100
# Out:
# sofifa_id      0.00
# player_url     0.00
# short_name     0.00
# long_name      0.00
# age            0.00
#               ...
# lb            11.14
# lcb           11.14
# cb            11.14
# rcb           11.14
# rb            11.14
# Length: 104, dtype: float64

# %%
df.contract_valid_until.dtypes
# Out:
# dtype('float64')

# %%
#find index
{df.columns.get_loc(col):col for col in  df.columns}
# Out:
# {0: 'sofifa_id',
#  1: 'player_url',
#  2: 'short_name',
#  3: 'long_name',
#  4: 'age',
#  5: 'dob',
#  6: 'height_cm',
#  7: 'weight_kg',
#  8: 'nationality',
#  9: 'club',
#  10: 'overall',
#  11: 'potential',
#  12: 'value_eur',
#  13: 'wage_eur',
#  14: 'player_positions',
#  15: 'preferred_foot',
#  16: 'international_reputation',
#  17: 'weak_foot',
#  18: 'skill_moves',
#  19: 'work_rate',
#  20: 'body_type',
#  21: 'real_face',
#  22: 'release_clause_eur',
#  23: 'player_tags',
#  24: 'team_position',
#  25: 'team_jersey_number',
#  26: 'loaned_from',
#  27: 'joined',
#  28: 'contract_valid_until',
#  29: 'nation_position',
#  30: 'nation_jersey_number',
#  31: 'pace',
#  32: 'shooting',
#  33: 'passing',
#  34: 'dribbling',
#  35: 'defending',
#  36: 'physic',
#  37: 'gk_diving',
#  38: 'gk_handling',
#  39: 'gk_kicking',
#  40: 'gk_reflexes',
#  41: 'gk_speed',
#  42: 'gk_positioning',
#  43: 'player_traits',
#  44: 'attacking_crossing',
#  45: 'attacking_finishing',
# ...

# %%
#dropping unnecessary ones

df.drop(df.columns[43:],axis=1,inplace=True)
df.drop(df.columns[20:24],axis=1,inplace=True)
df.drop(df.columns[22:24],axis=1,inplace=True)
df.drop(df.columns[11:14],axis=1,inplace=True)
df.drop(df.columns[5:7],axis=1,inplace=True)
df.drop(df.columns[3],axis=1,inplace=True)

# %%
df.drop(['team_jersey_number','nation_jersey_number'],axis=1,inplace=True)
del df['player_url']
del df['contract_valid_until']

# %%
df1_find_corr=df[[ 'age',
               'weight_kg', 'overall',
                 'weak_foot', 'skill_moves',
                
               'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic']]

# %%
df1_find_corr.corr()
# Out:
#                   age  weight_kg   overall  weak_foot  skill_moves      pace  \
# age          1.000000   0.237169  0.464305   0.073988     0.045277 -0.201211
# weight_kg    0.237169   1.000000  0.156522  -0.128568    -0.352060 -0.387138
# overall      0.464305   0.156522  1.000000   0.230276     0.401261  0.158866
# weak_foot    0.073988  -0.128568  0.230276   1.000000     0.343895  0.148527
# skill_moves  0.045277  -0.352060  0.401261   0.343895     1.000000  0.420886
# pace        -0.201211  -0.387138  0.158866   0.148527     0.420886  1.000000
# shooting     0.238990  -0.095442  0.497881   0.319034     0.625012  0.350101
# passing      0.330507  -0.182688  0.683954   0.281381     0.611950  0.289738
# dribbling    0.161913  -0.300792  0.601190   0.309823     0.714841  0.548527
# defending    0.259990   0.218564  0.334792  -0.105863    -0.209321 -0.304351
# physic       0.435292   0.581971  0.517214   0.000952    -0.066725 -0.196159
#
# ...

# %%
corr_matrix=df1_find_corr.corr()
corr_matrix["overall"].sort_values(ascending=False)
# Out:
# overall        1.000000
# passing        0.683954
# dribbling      0.601190
# physic         0.517214
# shooting       0.497881
# age            0.464305
# skill_moves    0.401261
# defending      0.334792
# weak_foot      0.230276
# pace           0.158866
# weight_kg      0.156522
# Name: overall, dtype: float64

# %%
df1=df.copy()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   sofifa_id                 18278 non-null  int64
#  1   short_name                18278 non-null  int32
#  2   age                       18278 non-null  int64
#  3   weight_kg                 18278 non-null  int64
#  4   nationality               18278 non-null  object
#  5   club                      18278 non-null  int32
#  6   overall                   18278 non-null  int64
#  7   player_positions          18278 non-null  int32
#  8   preferred_foot            18278 non-null  int32
#  9   international_reputation  18278 non-null  int64
#  10  weak_foot                 18278 non-null  int64
#  11  skill_moves               18278 non-null  int64
#  12  work_rate                 18278 non-null  int32
#  13  team_position             18038 non-null  object
# ...

# %%
df1.plot(kind="scatter",x="overall",y="passing")

# %%
df1=df.copy()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   sofifa_id                 18278 non-null  int64
#  1   short_name                18278 non-null  int32
#  2   age                       18278 non-null  int64
#  3   weight_kg                 18278 non-null  int64
#  4   nationality               18278 non-null  object
#  5   club                      18278 non-null  int32
#  6   overall                   18278 non-null  int64
#  7   player_positions          18278 non-null  int32
#  8   preferred_foot            18278 non-null  int32
#  9   international_reputation  18278 non-null  int64
#  10  weak_foot                 18278 non-null  int64
#  11  skill_moves               18278 non-null  int64
#  12  work_rate                 18278 non-null  int32
#  13  team_position             18038 non-null  object
# ...

# %%
df1
# Out:
#        sofifa_id  short_name  age  weight_kg nationality  club  overall  \
# 0         158023        9723   32         72   Argentina   224       94
# 1          20801        3164   34         83    Portugal   350       93
# 2         190871       12658   27         68      Brazil   462       92
# 3         200389        7851   26         87    Slovenia    63       91
# 4         183277        4459   28         74     Belgium   505       91
# ...          ...         ...  ...        ...         ...   ...      ...
# 18273     245006       15580   22         79    China PR    79       48
# 18274     250995       16833   22         66    China PR   574       48
# 18275     252332       17252   19         75    China PR   317       48
# 18276     251110       16760   18         74    China PR   573       48
# 18277     233449       13452   26         78    China PR   317       48
#
#        player_positions  preferred_foot  international_reputation  weak_foot  \
# ...

# %%
#MISSING VALUES
df1.isnull().sum()
# Out:
# sofifa_id                       0
# short_name                      0
# age                             0
# weight_kg                       0
# nationality                     0
# club                            0
# overall                         0
# player_positions                0
# preferred_foot                  0
# international_reputation        0
# weak_foot                       0
# skill_moves                     0
# work_rate                       0
# team_position                 240
# nation_position             17152
# pace                         2036
# shooting                     2036
# passing                      2036
# dribbling                    2036
# defending                    2036
# physic                       2036
# gk_diving                   16242
# gk_handling                 16242
# gk_kicking                  16242
# gk_reflexes                 16242
# gk_speed                    16242
# gk_positioning              16242
# dtype: int64

# %%
df1['gk_diving']=df1.gk_diving.fillna(df1.gk_diving.mean())
df1['gk_handling']=df1.gk_handling.fillna(df1.gk_handling.mean())
df1['gk_kicking']=df1.gk_kicking.fillna(df1.gk_kicking.mean())
df1['gk_reflexes']=df1.gk_reflexes.fillna(df.gk_reflexes.mean())
df1['gk_speed']=df1.gk_speed.fillna(df1.gk_speed.mean())
df1['gk_positioning']=df1.gk_positioning.fillna(df1.gk_positioning.mean())
df1['pace']=df1.pace.fillna(df1.pace.mean())
df1['shooting'] = df1.shooting.fillna(df1.shooting.mean())
df1['passing'] = df1.passing.fillna(df1.passing.mean())
df1['defending'] = df1.defending.fillna(df1.defending.mean())
df1['physic'] = df1.physic.fillna(df1.physic.mean())
df1['dribbling'] = df1.dribbling.fillna(df1.dribbling.mean())

# %%
df1['nation_position'] = df1.nation_position.fillna(df1.nation_position.value_counts().index[0])
df1['team_position'] = df1.team_position.fillna(df1.team_position.value_counts().index[0])
df1['nationality']=df1.team_position.fillna(df1.nationality.value_counts().index[0])

# %%
df1.isnull().sum()
# Out:
# sofifa_id                   0
# short_name                  0
# age                         0
# weight_kg                   0
# nationality                 0
# club                        0
# overall                     0
# player_positions            0
# preferred_foot              0
# international_reputation    0
# weak_foot                   0
# skill_moves                 0
# work_rate                   0
# team_position               0
# nation_position             0
# pace                        0
# shooting                    0
# passing                     0
# dribbling                   0
# defending                   0
# physic                      0
# gk_diving                   0
# gk_handling                 0
# gk_kicking                  0
# gk_reflexes                 0
# gk_speed                    0
# gk_positioning              0
# dtype: int64

# %%
#eg scale the whole data except pace
X = df1.drop('pace', axis = 1)
Y = df1['pace']

# %%
Y.head()
# Out:
# 0    87.000000
# 1    90.000000
# 2    91.000000
# 3    67.700899
# 4    91.000000
# Name: pace, dtype: float64

# %%
Y = df1.overall
column_features = ['pace', 'defending', 'passing', 'shooting', 'dribbling', 'player_positions','gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed','gk_diving' ,'gk_positioning']
X = df1[column_features]

# %%
X.head()
# Out:
#         pace  defending    passing   shooting  dribbling  player_positions  \
# 0  87.000000  39.000000  92.000000  92.000000  96.000000               544
# 1  90.000000  35.000000  82.000000  93.000000  89.000000               620
# 2  91.000000  32.000000  87.000000  85.000000  95.000000               344
# 3  67.700899  51.553503  57.233777  52.298301  62.531585               226
# 4  91.000000  35.000000  86.000000  83.000000  94.000000               350
#
#    gk_handling  gk_kicking  gk_reflexes   gk_speed  gk_diving  gk_positioning
# 0    63.146365   61.832515    66.390472  37.798625  65.422397       63.374754
# 1    63.146365   61.832515    66.390472  37.798625  65.422397       63.374754
# 2    63.146365   61.832515    66.390472  37.798625  65.422397       63.374754
# 3    92.000000   78.000000    89.000000  52.000000  87.000000       90.000000
# 4    63.146365   61.832515    66.390472  37.798625  65.422397       63.374754

# %%
Y.head()
# Out:
# 0    94
# 1    93
# 2    92
# 3    91
# 4    91
# Name: overall, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler , StandardScaler

# %%
scale = MinMaxScaler()
X=scale.fit_transform(X)

# %%
X[0:1]
# Out:
# array([[0.875     , 0.32      , 1.        , 0.98717949, 1.        ,
#         0.84735202, 0.42292731, 0.46262956, 0.45511642, 0.4867665 ,
#         0.46570428, 0.44749509]])

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_Y, val_Y = train_test_split(X, Y,test_size=0.2, random_state = 0)

# %%
X.shape
# Out:
# (18278, 12)

# %%
Y.shape
# Out:
# (18278,)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(train_X, train_Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(train_X, train_Y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
from sklearn.metrics import mean_squared_error
val_predictions = lin_reg.predict(train_X)
lin_mse = mean_squared_error(train_Y, val_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 3.9274956736284925

# %%
# Function to calculate mean absolute error
def mae(y_true, y_pred):
    return np.mean(abs(y_true - y_pred))

# Takes in a model, trains the model, and evaluates the model on the test set
def fit_and_evaluate(model):
    
    # Train the model
    model.fit(train_X, train_Y)
    
    # Make predictions and evalute
    model_pred = model.predict(val_X)
    model_mae = mae(val_Y, model_pred)
    
    # Return the performance metric
    return model_mae

# %%
lr = LinearRegression()
lr_mae = fit_and_evaluate(lr)

print('Linear Regression Performance on the test set: MAE = %0.4f' % lr_mae)
# Out:
# Linear Regression Performance on the test set: MAE = 3.0888

# %%
from sklearn.ensemble import RandomForestRegressor
#from sklearn.model import RandomForestRegressor
random_forest = RandomForestRegressor()
random_forest_mae = fit_and_evaluate(random_forest)
print('Random Forest Regression Performance on the test set: MAE = %0.4f' % random_forest_mae)
# Out:
# Random Forest Regression Performance on the test set: MAE = 1.0201
